# %%
import textwrap
from IPython.display import Markdown, display
from pypdf import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import numpy as np
import chromadb
import os
from chromadb.utils import embedding_functions
from chromadb import Client
from tqdm.notebook import trange, tqdm


# Keep your PDF extraction function as is
def convert_PDF_Text(pdf_path):
    reader = PdfReader(pdf_path)
    pdf_texts = [p.extract_text().strip() for p in reader.pages]
    # Filter the empty strings
    pdf_texts = [text for text in pdf_texts if text]
    print("Document: ", pdf_path, " chunk size: ", len(pdf_texts))
    return pdf_texts


# Helper for displaying text
def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))


# NEW FUNCTION: Modified chunk creation using sentence-based approach
def create_sentence_chunks(pdf_texts, chunk_size=800, chunk_overlap=200):
    # Combine all PDF texts into one string
    full_text = '\n\n'.join(pdf_texts)

    # Initialize sentence-based text splitter
    sentence_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n", ".", ":", ";", ",", " ", ""],  # Process in this order
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len
    )

    # Split text into chunks based on sentences
    chunks = sentence_splitter.split_text(full_text)

    print(f"\nTotal number of sentence-based chunks: {len(chunks)}")
    return chunks


# The rest of your embedding and collection logic remains the same
sentence_transformer_model = "distiluse-base-multilingual-cased-v1"
embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name=sentence_transformer_model)


def create_chroma_client(collection_name, embedding_function):
    chroma_client = Client()

    # Check if collection already exists and delete it
    existing_collections = [col.name for col in chroma_client.list_collections()]
    if collection_name in existing_collections:
        chroma_client.delete_collection(collection_name)

    # Create a new collection
    chroma_collection = chroma_client.create_collection(
        name=collection_name,
        embedding_function=embedding_function
    )

    return chroma_client, chroma_collection


def add_meta_data(chunks, title, category, initial_id):
    ids = [str(i + initial_id) for i in range(len(chunks))]
    filename = os.path.basename(title)
    metadata = {
        'document': filename,
        'category': category
    }
    metadatas = [metadata for i in range(len(chunks))]
    return ids, metadatas


def add_document_to_collection(ids, metadatas, chunks, chroma_collection):
    print("Before inserting, the size of the collection: ", chroma_collection.count())
    chroma_collection.upsert(ids=ids, metadatas=metadatas, documents=chunks)
    print("After inserting, the size of the collection: ", chroma_collection.count())
    return chroma_collection


def retrieveDocs(chroma_collection, query,file,n_results=10, return_only_docs=False):
    results = chroma_collection.query(query_texts=[query],
                                      include=["documents", "metadatas", 'distances'],
                                      where={"document":f"{file}.pdf"},
                                      n_results=n_results)
    if return_only_docs:
        return results['documents'][0]
    else:
        return results


def show_results(results, return_only_docs=False):
    if return_only_docs:
        retrieved_documents = results
        if len(retrieved_documents) == 0:
            print("No results found.")
            return
        for i, doc in enumerate(retrieved_documents):
            print(f"Document {i + 1}:")
            print("\tDocument Text: ")
            display(to_markdown(doc))
    else:
        retrieved_documents = results['documents'][0]
        if len(retrieved_documents) == 0:
            print("No results found.")
            return
        retrieved_documents_metadata = results['metadatas'][0]
        retrieved_documents_distances = results['distances'][0]
        print("------- Retrieved documents -------\n")

        for i, doc in enumerate(retrieved_documents):
            print(f"Document {i + 1}:")
            print("\tDocument Text: ")
            display(to_markdown(doc))
            # Extract filename from the full path
            full_path = retrieved_documents_metadata[i]['document']
            filename = os.path.basename(full_path)
            print(f"\tDocument Source: {filename}")
            print(f"\tDocument Source Type: {retrieved_documents_metadata[i]['category']}")
            print(f"\tDocument Distance: {retrieved_documents_distances[i]}")
            print("-" * 80)


def list_files_in_directory(directory_path):
    all_entries = os.listdir(directory_path)

    files_only = [entry for entry in all_entries
                  if os.path.isfile(os.path.join(directory_path, entry))]
    return files_only


def get_all_pdf_paths(
        directory_path="/Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları"):
    """
    Get all PDF file paths from the specified directory.

    Args:
        directory_path (str): Path to the directory containing PDF files

    Returns:
        list: List of full paths to all PDF files in the directory
    """
    all_files = list_files_in_directory(directory_path)
    pdf_files = [f for f in all_files if f.lower().endswith('.pdf')]
    full_paths = [os.path.join(directory_path, pdf_file) for pdf_file in pdf_files]
    return full_paths


def load_multiple_pdfs_to_ChromaDB(collection_name, sentence_transformer_model):
    """
    Load multiple PDFs into ChromaDB collection with proper chunking and embedding.

    Args:
        collection_name (str): Name of the ChromaDB collection
        sentence_transformer_model (str): Name of the sentence transformer model to use
        chromaDB_path (str, optional): Path to store ChromaDB data. Defaults to None.

    Returns:
        tuple: (chroma_client, chroma_collection)
    """
    # Initialize embedding function
    embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name=sentence_transformer_model)

    # Create or get ChromaDB client and collection
    chroma_client, chroma_collection = create_chroma_client(collection_name, embedding_function)

    # Get current ID for continuous indexing
    current_id = chroma_collection.count()

    # Get all PDF paths from the directory
    pdf_paths = get_all_pdf_paths()

    for pdf_path in pdf_paths:
        # Extract text from PDF
        pdf_texts = convert_PDF_Text(pdf_path)

        # Create sentence-based chunks
        chunks = create_sentence_chunks(pdf_texts)

        # Add metadata and get IDs
        ids, metadatas = add_meta_data(chunks, pdf_path, "PricePaper", current_id)

        # Update current_id for next document
        current_id += len(chunks)

        # Add to collection
        chroma_collection = add_document_to_collection(ids, metadatas, chunks, chroma_collection)

        print(f"Document: {pdf_path} added to the collection. New size: {chroma_collection.count()}")

    return chroma_client, chroma_collection


import KeywordAgent as keyword_agent

chroma_client, chroma_collection = load_multiple_pdfs_to_ChromaDB("UniPrices", sentence_transformer_model)
query = " Ted Üniversitesi İngilizce Öğretmenliği ücretleri"
keyword = keyword_agent.parse_keywords(query)
filtered_keyword=keyword.strip('"')
retrieved_documents = retrieveDocs(chroma_collection, query,filtered_keyword,10)
show_results(retrieved_documents)
# Out:
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/piriReisUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  0
# After inserting, the size of the collection:  1
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/piriReisUniversitesi.pdf added to the collection. New size: 1
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/dogusUniversitesi.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  1
# After inserting, the size of the collection:  8
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/dogusUniversitesi.pdf added to the collection. New size: 8
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulAydinUniversitesi.pdf  chunk size:  5
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  8
# After inserting, the size of the collection:  18
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulAydinUniversitesi.pdf added to the collection. New size: 18
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/turkHavaKurumuUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  18
# After inserting, the size of the collection:  25
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/turkHavaKurumuUniversitesi.pdf added to the collection. New size: 25
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulKulturUniversitesi.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 9
# Before inserting, the size of the collection:  25
# After inserting, the size of the collection:  34
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulKulturUniversitesi.pdf added to the collection. New size: 34
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSisliMeslekYuksekokulu.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  34
# After inserting, the size of the collection:  37
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSisliMeslekYuksekokulu.pdf added to the collection. New size: 37
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulKentUniversitesi.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  37
# After inserting, the size of the collection:  47
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulKentUniversitesi.pdf added to the collection. New size: 47
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/nuhNaciYazganUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  47
# After inserting, the size of the collection:  52
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/nuhNaciYazganUniversitesi.pdf added to the collection. New size: 52
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/izmirEkonomi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  52
# After inserting, the size of the collection:  60
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/izmirEkonomi.pdf added to the collection. New size: 60
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulRumeliUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  60
# After inserting, the size of the collection:  67
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulRumeliUniversitesi.pdf added to the collection. New size: 67
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/alanyaHepUniversitesi.pdf  chunk size:  6
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  67
# After inserting, the size of the collection:  75
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/alanyaHepUniversitesi.pdf added to the collection. New size: 75
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ktoKaratayUniversitesi.pdf  chunk size:  14
#
# Total number of sentence-based chunks: 27
# Before inserting, the size of the collection:  75
# After inserting, the size of the collection:  102
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ktoKaratayUniversitesi.pdf added to the collection. New size: 102
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSaglikVeSosyalBilimlerMeslekYuksekokulu.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  102
# After inserting, the size of the collection:  103
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSaglikVeSosyalBilimlerMeslekYuksekokulu.pdf added to the collection. New size: 103
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ufukUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  103
# After inserting, the size of the collection:  104
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ufukUniversitesi.pdf added to the collection. New size: 104
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/sabanciUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  104
# After inserting, the size of the collection:  106
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/sabanciUniversitesi.pdf added to the collection. New size: 106
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulAtlasUniversitesi.pdf  chunk size:  13
#
# Total number of sentence-based chunks: 21
# Before inserting, the size of the collection:  106
# After inserting, the size of the collection:  127
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulAtlasUniversitesi.pdf added to the collection. New size: 127
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulEsenyurtUniversitesi.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  127
# After inserting, the size of the collection:  135
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulEsenyurtUniversitesi.pdf added to the collection. New size: 135
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbul29MayisUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  135
# After inserting, the size of the collection:  137
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbul29MayisUniversitesi.pdf added to the collection. New size: 137
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/fenerbahceUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  137
# After inserting, the size of the collection:  141
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/fenerbahceUniversitesi.pdf added to the collection. New size: 141
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ibnHaldunUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  141
# After inserting, the size of the collection:  146
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ibnHaldunUniversitesi.pdf added to the collection. New size: 146
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/BilkentUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  146
# After inserting, the size of the collection:  149
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/BilkentUniversitesi.pdf added to the collection. New size: 149
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/antalyaBelekUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  149
# After inserting, the size of the collection:  152
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/antalyaBelekUniversitesi.pdf added to the collection. New size: 152
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulTicaretUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  152
# After inserting, the size of the collection:  156
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulTicaretUniversitesi.pdf added to the collection. New size: 156
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/hasanKalyoncuUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  156
# After inserting, the size of the collection:  158
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/hasanKalyoncuUniversitesi.pdf added to the collection. New size: 158
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kocaeliSaglikVeTeknolojiUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  158
# After inserting, the size of the collection:  162
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kocaeliSaglikVeTeknolojiUniversitesi.pdf added to the collection. New size: 162
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSabahattinZaimUniversitesi.pdf  chunk size:  7
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  162
# After inserting, the size of the collection:  172
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSabahattinZaimUniversitesi.pdf added to the collection. New size: 172
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kadirHasUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  172
# After inserting, the size of the collection:  175
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kadirHasUniversitesi.pdf added to the collection. New size: 175
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/avrasyaUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 6
# Before inserting, the size of the collection:  175
# After inserting, the size of the collection:  181
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/avrasyaUniversitesi.pdf added to the collection. New size: 181
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulGalataUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  181
# After inserting, the size of the collection:  189
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulGalataUniversitesi.pdf added to the collection. New size: 189
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ankaraBilimUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  189
# After inserting, the size of the collection:  196
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ankaraBilimUniversitesi.pdf added to the collection. New size: 196
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/baskentUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  196
# After inserting, the size of the collection:  198
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/baskentUniversitesi.pdf added to the collection. New size: 198
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/uskudarUniversitesi.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 11
# Before inserting, the size of the collection:  198
# After inserting, the size of the collection:  209
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/uskudarUniversitesi.pdf added to the collection. New size: 209
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/cankayaUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  209
# After inserting, the size of the collection:  210
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/cankayaUniversitesi.pdf added to the collection. New size: 210
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/demirciogluBilimUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  210
# After inserting, the size of the collection:  213
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/demirciogluBilimUniversitesi.pdf added to the collection. New size: 213
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/fatihSultanMehmetUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  213
# After inserting, the size of the collection:  217
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/fatihSultanMehmetUniversitesi.pdf added to the collection. New size: 217
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/mudanyaUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  217
# After inserting, the size of the collection:  224
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/mudanyaUniversitesi.pdf added to the collection. New size: 224
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/beykentUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  224
# After inserting, the size of the collection:  231
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/beykentUniversitesi.pdf added to the collection. New size: 231
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ankaraMedipolUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  231
# After inserting, the size of the collection:  235
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ankaraMedipolUniversitesi.pdf added to the collection. New size: 235
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/maltepeUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  235
# After inserting, the size of the collection:  245
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/maltepeUniversitesi.pdf added to the collection. New size: 245
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/yuksekIhtisasUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  245
# After inserting, the size of the collection:  249
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/yuksekIhtisasUniversitesi.pdf added to the collection. New size: 249
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/tobbUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  249
# After inserting, the size of the collection:  254
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/tobbUniversitesi.pdf added to the collection. New size: 254
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/tedUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  254
# After inserting, the size of the collection:  257
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/tedUniversitesi.pdf added to the collection. New size: 257
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/atilimUniversitesi.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  257
# After inserting, the size of the collection:  267
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/atilimUniversitesi.pdf added to the collection. New size: 267
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/yasarUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  267
# After inserting, the size of the collection:  269
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/yasarUniversitesi.pdf added to the collection. New size: 269
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/konyaGidaVeTarimUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  269
# After inserting, the size of the collection:  271
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/konyaGidaVeTarimUniversitesi.pdf added to the collection. New size: 271
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulGedikUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  271
# After inserting, the size of the collection:  278
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulGedikUniversitesi.pdf added to the collection. New size: 278
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/halicUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  278
# After inserting, the size of the collection:  283
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/halicUniversitesi.pdf added to the collection. New size: 283
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/lokmanHekimUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  283
# After inserting, the size of the collection:  286
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/lokmanHekimUniversitesi.pdf added to the collection. New size: 286
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kapadokyaUniversitesi.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  286
# After inserting, the size of the collection:  293
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kapadokyaUniversitesi.pdf added to the collection. New size: 293
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/bezmIAlemVakifUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  293
# After inserting, the size of the collection:  297
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/bezmIAlemVakifUniversitesi.pdf added to the collection. New size: 297
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/torosUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  297
# After inserting, the size of the collection:  300
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/torosUniversitesi.pdf added to the collection. New size: 300
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/cagUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  300
# After inserting, the size of the collection:  302
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/cagUniversitesi.pdf added to the collection. New size: 302
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istinyeUniversitesi.pdf  chunk size:  19
#
# Total number of sentence-based chunks: 18
# Before inserting, the size of the collection:  302
# After inserting, the size of the collection:  320
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istinyeUniversitesi.pdf added to the collection. New size: 320
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/beykozUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  320
# After inserting, the size of the collection:  324
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/beykozUniversitesi.pdf added to the collection. New size: 324
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/sankoUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  324
# After inserting, the size of the collection:  326
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/sankoUniversitesi.pdf added to the collection. New size: 326
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ostimTeknikUniversitesi.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 6
# Before inserting, the size of the collection:  326
# After inserting, the size of the collection:  332
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/ostimTeknikUniversitesi.pdf added to the collection. New size: 332
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSaglikVeTeknolojiUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  332
# After inserting, the size of the collection:  334
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulSaglikVeTeknolojiUniversitesi.pdf added to the collection. New size: 334
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulNisantasiUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  334
# After inserting, the size of the collection:  338
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulNisantasiUniversitesi.pdf added to the collection. New size: 338
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kocUniversitesi.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  338
# After inserting, the size of the collection:  341
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/kocUniversitesi.pdf added to the collection. New size: 341
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulYeniYuzyilUniversitesi.pdf  chunk size:  8
#
# Total number of sentence-based chunks: 16
# Before inserting, the size of the collection:  341
# After inserting, the size of the collection:  357
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/istanbulYeniYuzyilUniversitesi.pdf added to the collection. New size: 357
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/biruniUniversitesi.pdf  chunk size:  15
#
# Total number of sentence-based chunks: 17
# Before inserting, the size of the collection:  357
# After inserting, the size of the collection:  374
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/biruniUniversitesi.pdf added to the collection. New size: 374
# No results found.
