# %%
import textwrap
from IPython.display import Markdown, display
from pypdf import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import numpy as np
import chromadb
import os
from chromadb.utils import embedding_functions
from chromadb import Client
from tqdm.notebook import trange, tqdm


# Keep your PDF extraction function as is
def convert_PDF_Text(pdf_path):
    reader = PdfReader(pdf_path)
    pdf_texts = [p.extract_text().strip() for p in reader.pages]
    # Filter the empty strings
    pdf_texts = [text for text in pdf_texts if text]
    print("Document: ", pdf_path, " chunk size: ", len(pdf_texts))
    return pdf_texts


# Helper for displaying text
def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))


# NEW FUNCTION: Modified chunk creation using sentence-based approach
def create_sentence_chunks(pdf_texts, chunk_size=800, chunk_overlap=200):
    # Combine all PDF texts into one string
    full_text = '\n\n'.join(pdf_texts)

    # Initialize sentence-based text splitter
    sentence_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n", ".", ":", ";", ",", " ", ""],  # Process in this order
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len
    )

    # Split text into chunks based on sentences
    chunks = sentence_splitter.split_text(full_text)

    print(f"\nTotal number of sentence-based chunks: {len(chunks)}")
    return chunks


# The rest of your embedding and collection logic remains the same
sentence_transformer_model = "distiluse-base-multilingual-cased-v1"
embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name=sentence_transformer_model)


def create_chroma_client(collection_name, embedding_function):
    chroma_client = Client()

    # Check if collection already exists and delete it
    existing_collections = [col.name for col in chroma_client.list_collections()]
    if collection_name in existing_collections:
      chroma_client.delete_collection(collection_name)

    # Create a new collection
    chroma_collection = chroma_client.create_collection(
        name=collection_name,
        embedding_function=embedding_function
    )

    return chroma_client, chroma_collection


def add_meta_data(chunks, title, category, initial_id):
    ids = [str(i + initial_id) for i in range(len(chunks))]
    filename = os.path.basename(title)
    metadata = {
        'document': filename,
        'category': category
    }
    metadatas = [metadata for i in range(len(chunks))]
    return ids, metadatas


def add_document_to_collection(ids, metadatas, chunks, chroma_collection):
    print("Before inserting, the size of the collection: ", chroma_collection.count())
    chroma_collection.upsert(ids=ids, metadatas=metadatas, documents=chunks)
    print("After inserting, the size of the collection: ", chroma_collection.count())
    return chroma_collection


def retrieveDocs(chroma_collection, query, n_results=10, return_only_docs=False):
    results = chroma_collection.query(query_texts=[query],
                                      include=["documents", "metadatas", 'distances'],
                                      where_document={"$contains":"Atılım"},
                                      n_results=n_results)
    if return_only_docs:
        return results['documents'][0]
    else:
        return results


def show_results(results, return_only_docs=False):
    if return_only_docs:
        retrieved_documents = results
        if len(retrieved_documents) == 0:
            print("No results found.")
            return
        for i, doc in enumerate(retrieved_documents):
            print(f"Document {i + 1}:")
            print("\tDocument Text: ")
            display(to_markdown(doc))
    else:
        retrieved_documents = results['documents'][0]
        if len(retrieved_documents) == 0:
            print("No results found.")
            return
        retrieved_documents_metadata = results['metadatas'][0]
        retrieved_documents_distances = results['distances'][0]
        print("------- Retrieved documents -------\n")

        for i, doc in enumerate(retrieved_documents):
            print(f"Document {i + 1}:")
            print("\tDocument Text: ")
            display(to_markdown(doc))
            # Extract filename from the full path
            full_path = retrieved_documents_metadata[i]['document']
            filename = os.path.basename(full_path)
            print(f"\tDocument Source: {filename}")
            print(f"\tDocument Source Type: {retrieved_documents_metadata[i]['category']}")
            print(f"\tDocument Distance: {retrieved_documents_distances[i]}")
            print("-" * 80)



def list_files_in_directory(directory_path):
    all_entries = os.listdir(directory_path)

    files_only = [entry for entry in all_entries
                  if os.path.isfile(os.path.join(directory_path, entry))]
    return files_only


def get_all_pdf_paths(directory_path="/Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları"):
    """
    Get all PDF file paths from the specified directory.
    
    Args:
        directory_path (str): Path to the directory containing PDF files
        
    Returns:
        list: List of full paths to all PDF files in the directory
    """
    all_files = list_files_in_directory(directory_path)
    pdf_files = [f for f in all_files if f.lower().endswith('.pdf')]
    full_paths = [os.path.join(directory_path, pdf_file) for pdf_file in pdf_files]
    return full_paths


def load_multiple_pdfs_to_ChromaDB(collection_name, sentence_transformer_model):
    """
    Load multiple PDFs into ChromaDB collection with proper chunking and embedding.
    
    Args:
        collection_name (str): Name of the ChromaDB collection
        sentence_transformer_model (str): Name of the sentence transformer model to use
        chromaDB_path (str, optional): Path to store ChromaDB data. Defaults to None.
    
    Returns:
        tuple: (chroma_client, chroma_collection)
    """
    # Initialize embedding function
    embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name=sentence_transformer_model)
    
    # Create or get ChromaDB client and collection
    chroma_client, chroma_collection = create_chroma_client(collection_name, embedding_function)
    
    # Get current ID for continuous indexing
    current_id = chroma_collection.count()
    
    # Get all PDF paths from the directory
    pdf_paths = get_all_pdf_paths()
    
    for pdf_path in pdf_paths:
        # Extract text from PDF
        pdf_texts = convert_PDF_Text(pdf_path)
        
        # Create sentence-based chunks
        chunks = create_sentence_chunks(pdf_texts)
        
        # Add metadata and get IDs
        ids, metadatas = add_meta_data(chunks, pdf_path, "PricePaper", current_id)
        
        # Update current_id for next document
        current_id += len(chunks)
        
        # Add to collection
        chroma_collection = add_document_to_collection(ids, metadatas, chunks, chroma_collection)
        
        print(f"Document: {pdf_path} added to the collection. New size: {chroma_collection.count()}")
    
    return chroma_client, chroma_collection

chroma_client, chroma_collection = load_multiple_pdfs_to_ChromaDB("UniPrices", sentence_transformer_model)
query=" Elektrik elektronik fiyatları nelerdir"
retrieved_documents=retrieveDocs(chroma_collection, query, 10)
show_results(retrieved_documents)
# Out:
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istinye-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  19
#
# Total number of sentence-based chunks: 18
# Before inserting, the size of the collection:  0
# After inserting, the size of the collection:  18
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istinye-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 18
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Ticaret-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  18
# After inserting, the size of the collection:  22
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Ticaret-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 22
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Atlas-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  13
#
# Total number of sentence-based chunks: 21
# Before inserting, the size of the collection:  22
# After inserting, the size of the collection:  43
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Atlas-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 43
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Cankaya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  43
# After inserting, the size of the collection:  44
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Cankaya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 44
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Piri-Reis-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  44
# After inserting, the size of the collection:  45
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Piri-Reis-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 45
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Galata-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  45
# After inserting, the size of the collection:  53
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Galata-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 53
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ted-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  53
# After inserting, the size of the collection:  56
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ted-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 56
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ibn-Haldun-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  56
# After inserting, the size of the collection:  61
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ibn-Haldun-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 61
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Esenyurt-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  61
# After inserting, the size of the collection:  69
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Esenyurt-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 69
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Mudanya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  69
# After inserting, the size of the collection:  76
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Mudanya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 76
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ankara-Bilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  76
# After inserting, the size of the collection:  83
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ankara-Bilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 83
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Sabanci-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  83
# After inserting, the size of the collection:  85
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Sabanci-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 85
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ostim-Teknik-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 6
# Before inserting, the size of the collection:  85
# After inserting, the size of the collection:  91
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ostim-Teknik-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 91
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Hasan-Kalyoncu-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  91
# After inserting, the size of the collection:  93
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Hasan-Kalyoncu-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 93
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kto-Karatay-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  14
#
# Total number of sentence-based chunks: 27
# Before inserting, the size of the collection:  93
# After inserting, the size of the collection:  120
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kto-Karatay-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 120
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Nuh-Naci-Yazgan-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  120
# After inserting, the size of the collection:  125
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Nuh-Naci-Yazgan-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 125
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Yuksek-Ihtisas-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  125
# After inserting, the size of the collection:  129
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Yuksek-Ihtisas-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 129
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Maltepe-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  129
# After inserting, the size of the collection:  139
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Maltepe-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 139
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ihsan-Dogramaci-Bilkent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  139
# After inserting, the size of the collection:  142
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ihsan-Dogramaci-Bilkent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 142
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kapadokya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  142
# After inserting, the size of the collection:  149
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kapadokya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 149
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Demircioglu-Bilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  149
# After inserting, the size of the collection:  152
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Demircioglu-Bilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 152
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Beykent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  152
# After inserting, the size of the collection:  159
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Beykent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 159
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Sisli-Meslek-Yuksekokulu-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  159
# After inserting, the size of the collection:  162
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Sisli-Meslek-Yuksekokulu-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 162
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Lokman-Hekim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  162
# After inserting, the size of the collection:  165
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Lokman-Hekim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 165
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Biruni-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  15
#
# Total number of sentence-based chunks: 17
# Before inserting, the size of the collection:  165
# After inserting, the size of the collection:  182
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Biruni-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 182
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Sanko-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  182
# After inserting, the size of the collection:  184
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Sanko-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 184
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Aydin-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  5
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  184
# After inserting, the size of the collection:  194
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Aydin-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 194
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Beykoz-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  194
# After inserting, the size of the collection:  198
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Beykoz-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 198
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Sabahattin-Zaim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  7
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  198
# After inserting, the size of the collection:  208
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Sabahattin-Zaim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 208
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Toros-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  208
# After inserting, the size of the collection:  211
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Toros-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 211
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Nisantasi-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  211
# After inserting, the size of the collection:  215
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Nisantasi-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 215
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Dogus-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  215
# After inserting, the size of the collection:  222
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Dogus-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 222
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Halic-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  222
# After inserting, the size of the collection:  227
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Halic-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 227
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Yeni-Yuzyil-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  8
#
# Total number of sentence-based chunks: 16
# Before inserting, the size of the collection:  227
# After inserting, the size of the collection:  243
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Yeni-Yuzyil-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 243
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Fatih-Sultan-Mehmet-Vakif-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  243
# After inserting, the size of the collection:  247
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Fatih-Sultan-Mehmet-Vakif-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 247
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Izmir-Ekonomi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  247
# After inserting, the size of the collection:  255
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Izmir-Ekonomi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 255
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Koc-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  255
# After inserting, the size of the collection:  258
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Koc-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 258
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Alanya-HEP-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  6
#
# Total number of sentence-based chunks: 8
# Before inserting, the size of the collection:  258
# After inserting, the size of the collection:  266
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Alanya-HEP-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 266
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Yasar-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  266
# After inserting, the size of the collection:  268
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Yasar-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 268
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Saglik-ve-Teknoloji-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  268
# After inserting, the size of the collection:  270
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Saglik-ve-Teknoloji-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 270
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Kultur-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 9
# Before inserting, the size of the collection:  270
# After inserting, the size of the collection:  279
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Kultur-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 279
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Uskudar-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 11
# Before inserting, the size of the collection:  279
# After inserting, the size of the collection:  290
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Uskudar-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 290
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Antalya-Belek-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  290
# After inserting, the size of the collection:  293
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Antalya-Belek-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 293
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kadir-Has-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 3
# Before inserting, the size of the collection:  293
# After inserting, the size of the collection:  296
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kadir-Has-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 296
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ankara-Medipol-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  296
# After inserting, the size of the collection:  300
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ankara-Medipol-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 300
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/TOBB-Ekonomi-ve-Teknoloji-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 5
# Before inserting, the size of the collection:  300
# After inserting, the size of the collection:  305
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/TOBB-Ekonomi-ve-Teknoloji-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 305
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Gedik-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  305
# After inserting, the size of the collection:  312
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Gedik-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 312
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kocaeli-Saglik-ve-Teknoloji-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  312
# After inserting, the size of the collection:  316
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Kocaeli-Saglik-ve-Teknoloji-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 316
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Kent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  316
# After inserting, the size of the collection:  326
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Kent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 326
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Bezm-i-Alem-Vakif-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  326
# After inserting, the size of the collection:  330
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Bezm-i-Alem-Vakif-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 330
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Fenerbahce-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 4
# Before inserting, the size of the collection:  330
# After inserting, the size of the collection:  334
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Fenerbahce-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 334
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Atilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  4
#
# Total number of sentence-based chunks: 10
# Before inserting, the size of the collection:  334
# After inserting, the size of the collection:  344
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Atilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 344
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Turk-Hava-Kurumu-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  2
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  344
# After inserting, the size of the collection:  351
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Turk-Hava-Kurumu-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 351
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Baskent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  351
# After inserting, the size of the collection:  353
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Baskent-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 353
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Saglik-ve-Sosyal-Bilimler-Meslek-YuksekokuluEgitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  353
# After inserting, the size of the collection:  354
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Saglik-ve-Sosyal-Bilimler-Meslek-YuksekokuluEgitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 354
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-29-Mayis-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  354
# After inserting, the size of the collection:  356
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-29-Mayis-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 356
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Avrasya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025-1.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 6
# Before inserting, the size of the collection:  356
# After inserting, the size of the collection:  362
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Avrasya-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025-1.pdf added to the collection. New size: 362
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Cag-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  362
# After inserting, the size of the collection:  364
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Cag-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 364
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Konya-Gida-ve-Tarim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 2
# Before inserting, the size of the collection:  364
# After inserting, the size of the collection:  366
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Konya-Gida-ve-Tarim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 366
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Rumeli-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  3
#
# Total number of sentence-based chunks: 7
# Before inserting, the size of the collection:  366
# After inserting, the size of the collection:  373
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Istanbul-Rumeli-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 373
# Document:  /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ufuk-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf  chunk size:  1
#
# Total number of sentence-based chunks: 1
# Before inserting, the size of the collection:  373
# After inserting, the size of the collection:  374
# Document: /Users/harun/Documents/GitHub/AI-Powered-Regional-Cost-of-Living-Advisor/Search/Rag/Uni_fiyatları/Ufuk-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf added to the collection. New size: 374
# ------- Retrieved documents -------
#
# Document 1:
# 	Document Text:
# > Ameliyathane Hizmetleri: %50 İndirimli – 195.000 TL
# > Anestezi: %50 İndirimli – 195.000 TL
# > Diyaliz: %50 İndirimli – 195.000 TL
# > Elektronörofizyoloji: %50 İndirimli – 195.000 TL
# > İlk ve Acil Yardım: %50 İndirimli – 195.000 TL
# > Optisyenlik: %50 İndirimli – 195.000 TL
# > Patoloji Laboratuvar Teknikleri: %50 İndirimli – 195.000 TL
# > Radyoterapi: %50 İndirimli – 195.000 TL
# > Tıbbi Görüntüleme Teknikleri: %50 İndirimli – 195.000 TL
# > Tıbbi Laboratuvar Teknikleri: %50 İndirimli – 195.000 TL
# > Atılım Meslek Yüksekokulu
# > Mahkeme Büro Hizmetleri: %50 İndirimli – 195.000 TL
# > E-Ticaret ve Pazarlama: %50 İndirimli – 195.000 TL
# > Atılım Üniversitesi Eğitim Ücretleri ve Bursları 2023-2024
# > Atılım Üniversitesi’nde öğretim ücrete tabidir. 2023-2024 akademik yılında öğretim ücreti ;
# 	Document Source: Atilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf
# 	Document Source Type: PricePaper
# 	Document Distance: 1.2172417640686035
# --------------------------------------------------------------------------------
# Document 2:
# 	Document Text:
# > Atılım Üniversitesi Eğitim Ücretleri ve Bursları 2024-2025
# > Fen-Edebiyat Fakültesi
# > İngiliz Dili ve Edebiyatı (İngilizce): %50 İndirimli – 287.500 TL
# > İngilizce Mütercim ve Tercümanlık (İngilizce): % 25 İndirimli – 431.250 TL
# > Matematik (İngilizce): %50 İndirimli – 287.500 TL
# > Psikoloji (İngilizce): Ücretli 575.000 TL % 25 İndirimli – 431.250 TL
# > Güzel Sanatlar Tasarım ve Mimarlık Fakültesi
# > Endüstriyel Tasarım: %50 İndirimli – 287.500 TL
# > Grafik Tasarımı: %50 İndirimli – 287.500 TL
# > İç Mimarlık ve Çevre Tasarımı: % 25 İndirimli – 468.000 TL
# > Mimarlık: %50 İndirimli – 287.500 TL
# > Tekstil ve Moda Tasarımı: %50 İndirimli – 287.500 TL
# > Hukuk Fakültesi
# > Hukuk: %50 İndirimli – 287.500 TL
# > İşletme Fakültesi
# > Halkla İlişkiler ve Reklamcılık (İngilizce): %50 İndirimli – 287.500 TL
# 	Document Source: Atilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf
# 	Document Source Type: PricePaper
# 	Document Distance: 1.4100077152252197
# --------------------------------------------------------------------------------
# Document 3:
# 	Document Text:
# > Atılım Üniversitesi Eğitim Ücretleri ve Bursları 2023-2024
# > Atılım Üniversitesi’nde öğretim ücrete tabidir. 2023-2024 akademik yılında öğretim ücreti ;
# > Tıp Fakültesi (Ücretli) 386.000 TL (% 25 İndirim) 289.500 TL
# > Tıp Fakültesi (İngilizce) (Ücretli) 282.000 TL (% 25 İndirim) 211.500 TL
# > Hukuk Fakültesi (%50 İndirim) 141.000 TL
# > İşletme Fakültesi (tüm bölümler) (%50 İndirim) 141.000 TL
# > Sağlık Bilimleri Fakültesi (%50 İndirim) 141.000 TL
# > Mühendislik Fakültesi Yazılım Mühendisliği (% 25 İndirim) 211.500 TL
# > Mühendislik Fakültesi (diğer bölümler) (%50 İndirim) 141.000 TL
# > Adalet Meslek Yüksekokulu (%50 İndirim) 110.000 TL
# > Sağlık Hizmetleri Meslek Yüksekokulu (%50 İndirim) 110.000 TL
# > Fen Edebiyat Fakültesi Ücretleri
# 	Document Source: Atilim-Universitesi-Egitim-Ucretleri-ve-Burslari-2024-2025.pdf
# 	Document Source Type: PricePaper
# 	Document Distance: 1.4837664365768433
# --------------------------------------------------------------------------------
